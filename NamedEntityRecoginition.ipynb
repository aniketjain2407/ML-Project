# %% [markdown]
# # Reading the data

# %%
train_data = open(file='/content/train.txt',mode='r',encoding='utf-8')
test_data = open(file='/content/test.txt',mode='r',encoding='utf-8')
val_data = open(file='/content/validation.txt',mode='r',encoding='utf-8')

# %%
def read_data(file_path):
  tokens = []
  tags = []
  
  tweet_token = []
  tag_token = []

  for line in open(file_path,encoding='utf-8'):
    line = line.strip()   #removing extra spaces
    if not line: 
        tokens.append(tweet_token)
        tags.append(tag_token)
        tweet_token=[]
        tag_token=[]  #empty line
    else:
      token,tag = line.split()
      if token[0] == '@':
        token = '<USR>'
      if token[0:7]=='http://'or token[0:8]=='https://':
        token = '<URL>'
      tweet_token.append(token)
      tag_token.append(tag)

  return tokens , tags

# %%
train_tokens, train_tags = read_data('/content/train.txt')
validation_tokens, validation_tags = read_data('/content/validation.txt')
test_tokens, test_tags = read_data('/content/test.txt')

# %%
for i in range(2):
  for token,tag in zip(train_tokens[i],train_tags[i]):
    print('%s\t%s '%(token,tag))
# Out:
# RT	O
# <USR>	O
# :	O
# Online	O
# ticket	O
# sales	O
# for	O
# Ghostland	B-musicartist
# Observatory	I-musicartist
# extended	O
# until	O
# 6	O
# PM	O
# EST	O
# due	O
# to	O
# high	O
# demand	O
# .	O
# Get	O
# them	O
# before	O
# they	O
# sell	O
# out	O
# ...	O
# Apple	B-product
# MacBook	I-product
# Pro	I-product
# A1278	I-product
# 13.3	I-product
# "	I-product
# Laptop	I-product
# -	I-product
# MD101LL/A	I-product
# (	O
# June	O
# ,	O
# 2012	O
# )	O
# -	O
# Full	O
# read	O
# by	O
# eBay	B-company
# <URL>	O
# <URL>	O

# %% [markdown]
# # building the dictionaries

# %%
from collections import defaultdict
import numpy as np

# %%
from tqdm import tqdm
# setting special token for padding and unknown words
def build_dict(tokens_or_tags, special_tokens):
    # Create a dictionary with default value 0
    tok2idx = defaultdict(lambda: 0)
    idx2tok = []
    count = 0
    for i in special_tokens:
      tok2idx[i]=count
      count = count + 1
      idx2tok.append(i)
    for words in tqdm(tokens_or_tags):
      for word in words:
        if word not in tok2idx.keys():
          tok2idx[word]=count
          count=count+1
          idx2tok.append(word)
    return tok2idx, idx2tok

# %%
special_tokens = ['<UNK>', '<PAD>']
special_tags = ['O']

# %%
token2idx, idx2token = build_dict(train_tokens + validation_tokens, special_tokens)
tag2idx, idx2tag = build_dict(train_tags, special_tags)
# Out:
# 100%|██████████| 6519/6519 [00:00<00:00, 173770.84it/s]
# 100%|██████████| 5795/5795 [00:00<00:00, 385075.91it/s]

# %%
print(token2idx['<UNK>'],tag2idx['O'])
# Out:
# 0 0

# %%
def words2idxs(tokens_list):
    return [token2idx[word] for word in tokens_list]

def tags2idxs(tags_list):
    return [tag2idx[tag] for tag in tags_list]

def idxs2words(idxs):
    return [idx2token[idx] for idx in idxs]

def idxs2tags(idxs):
    return [idx2tag[idx] for idx in idxs]

# %% [markdown]
# # Generating mini-batches

# %%
def batches_generator(batch_size, tokens, tags,
                      shuffle=True, allow_smaller_last_batch=True):
    
    n_samples = len(tokens)
    if shuffle:
        order = np.random.permutation(n_samples)
    else:
        order = np.arange(n_samples)

    n_batches = n_samples // batch_size   # no of batches
    if allow_smaller_last_batch and n_samples % batch_size:
        n_batches += 1

    for k in range(n_batches):
        batch_start = k * batch_size
        batch_end = min((k + 1) * batch_size, n_samples)
        current_batch_size = batch_end - batch_start
        x_list = []
        y_list = []
        max_len_token = 0
        for idx in order[batch_start: batch_end]:
            x_list.append(words2idxs(tokens[idx]))
            y_list.append(tags2idxs(tags[idx]))
            max_len_token = max(max_len_token, len(tags[idx]))
            
        # Fill in the data into numpy nd-arrays filled with padding indices.
        x = np.ones([current_batch_size, max_len_token], dtype=np.int32) * token2idx['<PAD>']
        y = np.ones([current_batch_size, max_len_token], dtype=np.int32) * tag2idx['O']
        lengths = np.zeros(current_batch_size, dtype=np.int32)
        for n in range(current_batch_size):
            utt_len = len(x_list[n])
            x[n, :utt_len] = x_list[n]
            lengths[n] = utt_len
            y[n, :utt_len] = y_list[n]
        yield x, y, lengths

# %% [markdown]
# # Building a network / Model

# %%
import tensorflow as tf
import numpy as np

# %%
# imporing library
import keras
import keras.utils
from keras import initializers
from keras.layers import Bidirectional,Input,LSTM
from keras.layers import Dense,Activation,Lambda,Embedding,Dropout,concatenate
from keras.optimizers import Adam
from keras.losses import categorical_crossentropy
from keras.metrics import PrecisionAtRecall
from keras.models import Model, Sequential
from keras.backend import placeholder
import keras.backend as K
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
input_batch = placeholder(dtype=tf.int32 , shape=[None , None], name = 'input_batch' )
ground_truth_tags = placeholder(dtype=tf.int32 , shape=[None ,None],name='ground-truth_tags')
lengths = placeholder(dtype=tf.int32, shape= [None], name ='lengths') #for the length of sequences
#dropout_ph = placeholder_with_default(tf.cast(1.0, tf.float32), shape=[]) # dropout placeholder
learning_rate_ph = placeholder(dtype=tf.float32,name='learning_rate_ph')

# %%
def ner(vocabulary_size,embedding_dim,rnn_units,n_tags):
  # gnerating embedding layer
  # length = max length of the correspoding batches in training set
  #input_batch = placeholder(shape=[None,max_length],dtype=tf.float64,name='input_batch')

  sentence_indices = Input(shape=(None,))
  initial_embedding_matrix = np.random.rand(vocabulary_size,embedding_dim)/np.sqrt(embedding_dim)
  embedding_layer = Embedding(input_dim = vocabulary_size,output_dim=embedding_dim,embeddings_initializer=initializers.RandomNormal())
  #embedding_layer.astype('tf.float64')
  # propagating setences_indices through embedding layer
  embeddings = embedding_layer(sentence_indices)
  # dropout
  dropout = Dropout(rate=0.8)(embeddings)
  # bi-LSTm layer where output is the concatenation of both the forward and backward state
  BLSTM = Bidirectional(LSTM(units=rnn_units,return_sequences=True),merge_mode='concat')(dropout)
  # Dense layer foloowed by softmax
  dense = Dense(units = n_tags)(BLSTM)
  out = Activation('softmax')(dense)
  # taking argmax
  #out = keras.backend.argmax(activation,axis=-1)
  # definfing the model
  model = Model(inputs=sentence_indices,outputs= out)
  
  return model

# %%
model = ner(len(token2idx),200,200,len(tag2idx))

# %%
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, None)]            0
# _________________________________________________________________
# embedding (Embedding)        (None, None, 200)         4101000
# _________________________________________________________________
# dropout (Dropout)            (None, None, 200)         0
# _________________________________________________________________
# bidirectional (Bidirectional (None, None, 400)         641600
# _________________________________________________________________
# dense (Dense)                (None, None, 21)          8421
# _________________________________________________________________
# activation (Activation)      (None, None, 21)          0
# =================================================================
# Total params: 4,751,021
# Trainable params: 4,751,021
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = Adam(learning_rate=0.005,decay=np.sqrt(2))
#loss= categorical_crossentropy(y_true=y_train,)
#loss = categorical_crossentropy(from_logits=True)
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'],)

# %% [markdown]
# # Training of Model

# %%
n_epochs = 4
batch_size = 32

# %%
len(tag2idx)
# Out:
# 21

# %%
print('Start training... \n')

for epoch in tqdm(range(n_epochs)):
  print('-' * 20 + ' Epoch {} '.format(epoch+1) + 'of {} '.format(n_epochs) + '-' * 20)

  for x_batch,y_batch,_ in batches_generator(batch_size,train_tokens,train_tags):
    y_batch = tf.keras.backend.one_hot(y_batch,num_classes=len(tag2idx))
    model.fit(x_batch,y_batch)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# Start training...
#
# -------------------- Epoch 1 of 4 --------------------
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0257 - accuracy: 0.0339
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8690 - accuracy: 0.6783
# 1/1 [==============================] - 0s 2ms/step - loss: 2.7097 - accuracy: 0.8416
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3868 - accuracy: 0.9202
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2294 - accuracy: 0.9289
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7322 - accuracy: 0.9453
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4704 - accuracy: 0.9333
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0205 - accuracy: 0.9596
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4050 - accuracy: 0.9722
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4514 - accuracy: 0.9482
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5738 - accuracy: 0.9325
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4636 - accuracy: 0.9498
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2541 - accuracy: 0.9717
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3749 - accuracy: 0.9577
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3156 - accuracy: 0.9644
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3735 - accuracy: 0.9663
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4154 - accuracy: 0.9568
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2448 - accuracy: 0.9732
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3157 - accuracy: 0.9658
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4583 - accuracy: 0.9561
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4093 - accuracy: 0.9556
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4906 - accuracy: 0.9431
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3254 - accuracy: 0.9652
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3215 - accuracy: 0.9580
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2559 - accuracy: 0.9725
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3654 - accuracy: 0.9536
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2678 - accuracy: 0.9639
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2529 - accuracy: 0.9629
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2999 - accuracy: 0.9609
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3695 - accuracy: 0.9458
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2425 - accuracy: 0.9676
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2403 - accuracy: 0.9679
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2527 - accuracy: 0.9647
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2370 - accuracy: 0.9640
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2774 - accuracy: 0.9623
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4007 - accuracy: 0.9364
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2647 - accuracy: 0.9637
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2899 - accuracy: 0.9531
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2262 - accuracy: 0.9666
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2978 - accuracy: 0.9520
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3055 - accuracy: 0.9537
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3196 - accuracy: 0.9515
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3150 - accuracy: 0.9551
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2707 - accuracy: 0.9623
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1673 - accuracy: 0.9744
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2624 - accuracy: 0.9583
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2956 - accuracy: 0.9552
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3201 - accuracy: 0.9504
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3027 - accuracy: 0.9531
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2426 - accuracy: 0.9657
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2183 - accuracy: 0.9688
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3257 - accuracy: 0.9506
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2202 - accuracy: 0.9631
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4290 - accuracy: 0.9286
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2598 - accuracy: 0.9583
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2420 - accuracy: 0.9635
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2685 - accuracy: 0.9573
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1768 - accuracy: 0.9758
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2990 - accuracy: 0.9541
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1966 - accuracy: 0.9725
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2251 - accuracy: 0.9644
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2896 - accuracy: 0.9536
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2539 - accuracy: 0.9615
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5132 - accuracy: 0.9074
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2630 - accuracy: 0.9583
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2090 - accuracy: 0.9640
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2041 - accuracy: 0.9710
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2415 - accuracy: 0.9605
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1828 - accuracy: 0.9740
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2547 - accuracy: 0.9590
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3197 - accuracy: 0.9461
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2502 - accuracy: 0.9607
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2353 - accuracy: 0.9607
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1748 - accuracy: 0.9736
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1632 - accuracy: 0.9758
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2253 - accuracy: 0.9655
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2719 - accuracy: 0.9563
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3068 - accuracy: 0.9561
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3298 - accuracy: 0.9486
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4343 - accuracy: 0.9366
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2765 - accuracy: 0.9569
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2146 - accuracy: 0.9659
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2296 - accuracy: 0.9625
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2156 - accuracy: 0.9668
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2705 - accuracy: 0.9583
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2278 - accuracy: 0.9635
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2897 - accuracy: 0.9554
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2741 - accuracy: 0.9564
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3065 - accuracy: 0.9486
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2564 - accuracy: 0.9600
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2493 - accuracy: 0.9621
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2624 - accuracy: 0.9595
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2101 - accuracy: 0.9652
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3204 - accuracy: 0.9492
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2169 - accuracy: 0.9643
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3010 - accuracy: 0.9515
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2922 - accuracy: 0.9531
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1483 - accuracy: 0.9777
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1344 - accuracy: 0.9795
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3030 - accuracy: 0.9496
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2444 - accuracy: 0.9597
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4240 - accuracy: 0.9260
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2371 - accuracy: 0.9609
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3058 - accuracy: 0.9483
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2914 - accuracy: 0.9506
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1865 - accuracy: 0.9719
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2832 - accuracy: 0.9502
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3488 - accuracy: 0.9375
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2840 - accuracy: 0.9542
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2879 - accuracy: 0.9536
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2423 - accuracy: 0.9593
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2782 - accuracy: 0.9515
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1556 - accuracy: 0.9761
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2285 - accuracy: 0.9640
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2262 - accuracy: 0.9650
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1586 - accuracy: 0.9756
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2177 - accuracy: 0.9648
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1575 - accuracy: 0.9754
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2394 - accuracy: 0.9597
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3167 - accuracy: 0.9476
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1705 - accuracy: 0.9743
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3796 - accuracy: 0.9325
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1952 - accuracy: 0.9688
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2574 - accuracy: 0.9639
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2366 - accuracy: 0.9600
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2446 - accuracy: 0.9615
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2715 - accuracy: 0.9540
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3832 - accuracy: 0.9325
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2463 - accuracy: 0.9600
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2375 - accuracy: 0.9609
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1627 - accuracy: 0.9743
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4431 - accuracy: 0.9248
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2480 - accuracy: 0.9621
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3161 - accuracy: 0.9440
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1828 - accuracy: 0.9698
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1400 - accuracy: 0.9798
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3848 - accuracy: 0.9321
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2840 - accuracy: 0.9509
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2291 - accuracy: 0.9642
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2168 - accuracy: 0.9677
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3000 - accuracy: 0.9515
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1471 - accuracy: 0.9775
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3182 - accuracy: 0.9435
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2420 - accuracy: 0.9615
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3296 - accuracy: 0.9386
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2498 - accuracy: 0.9602
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2367 - accuracy: 0.9590
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1758 - accuracy: 0.9736
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2004 - accuracy: 0.9698
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3021 - accuracy: 0.9472
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2037 - accuracy: 0.9677
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2015 - accuracy: 0.9645
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3441 - accuracy: 0.9386
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1971 - accuracy: 0.9688
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3070 - accuracy: 0.9468
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3112 - accuracy: 0.9449
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2664 - accuracy: 0.9516
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2628 - accuracy: 0.9563
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1734 - accuracy: 0.9717
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2825 - accuracy: 0.9494
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3253 - accuracy: 0.9425
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1797 - accuracy: 0.9688
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3093 - accuracy: 0.9463
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2447 - accuracy: 0.9621
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3659 - accuracy: 0.9292
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2201 - accuracy: 0.9632
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2276 - accuracy: 0.9615
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3387 - accuracy: 0.9404
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2462 - accuracy: 0.9573
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2599 - accuracy: 0.9547
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1726 - accuracy: 0.9728
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2577 - accuracy: 0.9546
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3107 - accuracy: 0.9456
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3530 - accuracy: 0.9405
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2404 - accuracy: 0.9606
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1893 - accuracy: 0.9670
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3473 - accuracy: 0.9397
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2675 - accuracy: 0.9545
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2320 - accuracy: 0.9607
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3195 - accuracy: 0.9469
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3317 - accuracy: 0.9407
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5597 - accuracy: 0.9091
#  25%|██▌       | 1/4 [00:56<02:50, 56.69s/it]
# -------------------- Epoch 2 of 4 --------------------
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2529 - accuracy: 0.9576
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2599 - accuracy: 0.9551
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2927 - accuracy: 0.9469
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1952 - accuracy: 0.9657
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2163 - accuracy: 0.9644
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2277 - accuracy: 0.9632
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2104 - accuracy: 0.9631
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3393 - accuracy: 0.9418
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2571 - accuracy: 0.9594
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1868 - accuracy: 0.9677
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3174 - accuracy: 0.9407
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2181 - accuracy: 0.9617
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3012 - accuracy: 0.9495
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2294 - accuracy: 0.9571
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2898 - accuracy: 0.9537
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2060 - accuracy: 0.9655
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2455 - accuracy: 0.9589
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2610 - accuracy: 0.9587
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2262 - accuracy: 0.9604
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2476 - accuracy: 0.9542
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2057 - accuracy: 0.9600
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2659 - accuracy: 0.9460
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2627 - accuracy: 0.9518
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3338 - accuracy: 0.9393
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1603 - accuracy: 0.9727
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3376 - accuracy: 0.9385
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1447 - accuracy: 0.9775
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1851 - accuracy: 0.9677
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2375 - accuracy: 0.9570
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2258 - accuracy: 0.9564
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1642 - accuracy: 0.9728
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3350 - accuracy: 0.9321
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1653 - accuracy: 0.9738
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1752 - accuracy: 0.9688
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2333 - accuracy: 0.9573
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2061 - accuracy: 0.9654
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3067 - accuracy: 0.9414
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2311 - accuracy: 0.9587
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1528 - accuracy: 0.9735
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1433 - accuracy: 0.9752
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2963 - accuracy: 0.9396
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3019 - accuracy: 0.9438
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2195 - accuracy: 0.9644
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2444 - accuracy: 0.9546
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2433 - accuracy: 0.9587
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1922 - accuracy: 0.9688
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2637 - accuracy: 0.9479
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2463 - accuracy: 0.9518
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1960 - accuracy: 0.9643
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1597 - accuracy: 0.9697
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1965 - accuracy: 0.9597
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1896 - accuracy: 0.9641
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3159 - accuracy: 0.9364
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2145 - accuracy: 0.9597
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1483 - accuracy: 0.9748
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2564 - accuracy: 0.9486
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1856 - accuracy: 0.9688
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1940 - accuracy: 0.9700
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3228 - accuracy: 0.9397
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2629 - accuracy: 0.9498
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2323 - accuracy: 0.9596
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2489 - accuracy: 0.9482
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1810 - accuracy: 0.9663
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2496 - accuracy: 0.9472
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1899 - accuracy: 0.9637
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1995 - accuracy: 0.9640
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2529 - accuracy: 0.9473
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1606 - accuracy: 0.9699
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2396 - accuracy: 0.9575
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1242 - accuracy: 0.9768
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1824 - accuracy: 0.9688
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2966 - accuracy: 0.9424
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3127 - accuracy: 0.9365
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2245 - accuracy: 0.9577
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1621 - accuracy: 0.9697
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2517 - accuracy: 0.9531
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2612 - accuracy: 0.9546
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2658 - accuracy: 0.9479
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1963 - accuracy: 0.9621
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1973 - accuracy: 0.9634
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1515 - accuracy: 0.9707
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1470 - accuracy: 0.9752
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2317 - accuracy: 0.9552
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2349 - accuracy: 0.9555
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2328 - accuracy: 0.9536
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2443 - accuracy: 0.9512
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1567 - accuracy: 0.9716
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1591 - accuracy: 0.9716
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2499 - accuracy: 0.9542
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1896 - accuracy: 0.9656
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3875 - accuracy: 0.9190
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2010 - accuracy: 0.9612
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1146 - accuracy: 0.9821
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1270 - accuracy: 0.9798
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1528 - accuracy: 0.9733
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2584 - accuracy: 0.9500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1241 - accuracy: 0.9763
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2640 - accuracy: 0.9482
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1962 - accuracy: 0.9640
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2135 - accuracy: 0.9614
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2175 - accuracy: 0.9542
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2639 - accuracy: 0.9483
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2137 - accuracy: 0.9565
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2273 - accuracy: 0.9574
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2294 - accuracy: 0.9554
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1808 - accuracy: 0.9678
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1972 - accuracy: 0.9655
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2186 - accuracy: 0.9572
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2604 - accuracy: 0.9482
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3069 - accuracy: 0.9375
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2112 - accuracy: 0.9556
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3615 - accuracy: 0.9255
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0802 - accuracy: 0.9879
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2388 - accuracy: 0.9473
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1305 - accuracy: 0.9770
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2556 - accuracy: 0.9482
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2158 - accuracy: 0.9570
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1888 - accuracy: 0.9642
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1373 - accuracy: 0.9724
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1618 - accuracy: 0.9729
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2324 - accuracy: 0.9547
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1129 - accuracy: 0.9819
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1776 - accuracy: 0.9637
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1616 - accuracy: 0.9647
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2859 - accuracy: 0.9479
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1012 - accuracy: 0.9835
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1849 - accuracy: 0.9655
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2779 - accuracy: 0.9453
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2260 - accuracy: 0.9506
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1389 - accuracy: 0.9708
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1929 - accuracy: 0.9625
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1872 - accuracy: 0.9648
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2336 - accuracy: 0.9542
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2612 - accuracy: 0.9434
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3736 - accuracy: 0.9170
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2430 - accuracy: 0.9469
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3240 - accuracy: 0.9340
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2233 - accuracy: 0.9509
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2475 - accuracy: 0.9488
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2386 - accuracy: 0.9536
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2033 - accuracy: 0.9609
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2011 - accuracy: 0.9591
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3035 - accuracy: 0.9343
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1813 - accuracy: 0.9661
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2165 - accuracy: 0.9551
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2010 - accuracy: 0.9602
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1880 - accuracy: 0.9558
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2612 - accuracy: 0.9435
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2633 - accuracy: 0.9470
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2784 - accuracy: 0.9425
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2787 - accuracy: 0.9417
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2105 - accuracy: 0.9564
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2694 - accuracy: 0.9440
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2174 - accuracy: 0.9556
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2468 - accuracy: 0.9558
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1956 - accuracy: 0.9561
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2747 - accuracy: 0.9440
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2073 - accuracy: 0.9577
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2649 - accuracy: 0.9475
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1273 - accuracy: 0.9732
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1705 - accuracy: 0.9647
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1826 - accuracy: 0.9600
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2651 - accuracy: 0.9421
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2679 - accuracy: 0.9450
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1362 - accuracy: 0.9718
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2375 - accuracy: 0.9472
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2727 - accuracy: 0.9491
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2017 - accuracy: 0.9572
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2298 - accuracy: 0.9521
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1317 - accuracy: 0.9760
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2297 - accuracy: 0.9502
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1580 - accuracy: 0.9727
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2674 - accuracy: 0.9446
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2306 - accuracy: 0.9486
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1832 - accuracy: 0.9604
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3032 - accuracy: 0.9365
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2051 - accuracy: 0.9569
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1845 - accuracy: 0.9629
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1808 - accuracy: 0.9629
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2057 - accuracy: 0.9594
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1416 - accuracy: 0.9688
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1379 - accuracy: 0.9798
#  50%|█████     | 2/4 [01:45<01:48, 54.47s/it]
# -------------------- Epoch 3 of 4 --------------------
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1622 - accuracy: 0.9659
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2483 - accuracy: 0.9453
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1569 - accuracy: 0.9667
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2038 - accuracy: 0.9531
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2032 - accuracy: 0.9587
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1205 - accuracy: 0.9741
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2392 - accuracy: 0.9476
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0884 - accuracy: 0.9819
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3018 - accuracy: 0.9290
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1358 - accuracy: 0.9745
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1116 - accuracy: 0.9752
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1411 - accuracy: 0.9719
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2188 - accuracy: 0.9521
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1285 - accuracy: 0.9743
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2926 - accuracy: 0.9387
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1198 - accuracy: 0.9766
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1927 - accuracy: 0.9603
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1493 - accuracy: 0.9698
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1797 - accuracy: 0.9623
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2624 - accuracy: 0.9442
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1377 - accuracy: 0.9724
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1636 - accuracy: 0.9678
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1684 - accuracy: 0.9627
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1585 - accuracy: 0.9647
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2066 - accuracy: 0.9556
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1900 - accuracy: 0.9609
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2687 - accuracy: 0.9345
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1976 - accuracy: 0.9536
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2063 - accuracy: 0.9558
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2105 - accuracy: 0.9517
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2359 - accuracy: 0.9458
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2522 - accuracy: 0.9420
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1185 - accuracy: 0.9709
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2647 - accuracy: 0.9375
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1651 - accuracy: 0.9632
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1603 - accuracy: 0.9641
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1198 - accuracy: 0.9727
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2536 - accuracy: 0.9446
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1902 - accuracy: 0.9612
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1555 - accuracy: 0.9629
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1927 - accuracy: 0.9609
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2401 - accuracy: 0.9487
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1107 - accuracy: 0.9792
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1511 - accuracy: 0.9612
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1103 - accuracy: 0.9778
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2090 - accuracy: 0.9509
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1648 - accuracy: 0.9615
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2643 - accuracy: 0.9363
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2080 - accuracy: 0.9521
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1975 - accuracy: 0.9587
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1659 - accuracy: 0.9632
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2023 - accuracy: 0.9537
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2328 - accuracy: 0.9453
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2044 - accuracy: 0.9542
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1822 - accuracy: 0.9504
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1859 - accuracy: 0.9637
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2027 - accuracy: 0.9516
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2104 - accuracy: 0.9500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1860 - accuracy: 0.9568
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1832 - accuracy: 0.9677
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1805 - accuracy: 0.9601
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1071 - accuracy: 0.9784
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2589 - accuracy: 0.9446
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2210 - accuracy: 0.9546
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1995 - accuracy: 0.9591
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1158 - accuracy: 0.9771
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1341 - accuracy: 0.9697
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1887 - accuracy: 0.9561
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1706 - accuracy: 0.9563
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2289 - accuracy: 0.9495
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1223 - accuracy: 0.9757
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1889 - accuracy: 0.9598
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2337 - accuracy: 0.9456
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1530 - accuracy: 0.9616
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1301 - accuracy: 0.9741
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1068 - accuracy: 0.9786
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1222 - accuracy: 0.9721
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2068 - accuracy: 0.9554
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1609 - accuracy: 0.9667
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1559 - accuracy: 0.9666
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1135 - accuracy: 0.9728
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2220 - accuracy: 0.9457
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1337 - accuracy: 0.9717
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2622 - accuracy: 0.9425
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2122 - accuracy: 0.9517
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1443 - accuracy: 0.9707
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2045 - accuracy: 0.9537
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1823 - accuracy: 0.9612
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1594 - accuracy: 0.9619
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1846 - accuracy: 0.9580
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2047 - accuracy: 0.9513
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1434 - accuracy: 0.9656
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0991 - accuracy: 0.9778
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1742 - accuracy: 0.9580
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1984 - accuracy: 0.9561
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1600 - accuracy: 0.9609
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2388 - accuracy: 0.9453
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2828 - accuracy: 0.9444
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2464 - accuracy: 0.9450
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2218 - accuracy: 0.9494
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1897 - accuracy: 0.9587
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2830 - accuracy: 0.9397
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1538 - accuracy: 0.9670
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1368 - accuracy: 0.9670
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1575 - accuracy: 0.9637
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2377 - accuracy: 0.9466
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2378 - accuracy: 0.9425
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1316 - accuracy: 0.9708
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1330 - accuracy: 0.9678
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0942 - accuracy: 0.9768
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0781 - accuracy: 0.9805
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2062 - accuracy: 0.9570
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2075 - accuracy: 0.9546
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2408 - accuracy: 0.9375
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1903 - accuracy: 0.9590
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2335 - accuracy: 0.9516
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1685 - accuracy: 0.9651
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2293 - accuracy: 0.9521
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1894 - accuracy: 0.9561
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1730 - accuracy: 0.9641
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2087 - accuracy: 0.9558
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2002 - accuracy: 0.9591
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2478 - accuracy: 0.9415
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1226 - accuracy: 0.9705
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1063 - accuracy: 0.9768
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2378 - accuracy: 0.9421
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3583 - accuracy: 0.9275
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1813 - accuracy: 0.9640
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2159 - accuracy: 0.9517
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1495 - accuracy: 0.9688
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2185 - accuracy: 0.9531
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2345 - accuracy: 0.9453
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1878 - accuracy: 0.9565
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1672 - accuracy: 0.9558
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1772 - accuracy: 0.9564
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2545 - accuracy: 0.9498
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1618 - accuracy: 0.9667
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1817 - accuracy: 0.9579
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1366 - accuracy: 0.9647
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1568 - accuracy: 0.9665
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1735 - accuracy: 0.9531
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2324 - accuracy: 0.9555
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2398 - accuracy: 0.9455
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2381 - accuracy: 0.9504
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1433 - accuracy: 0.9669
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1663 - accuracy: 0.9629
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1548 - accuracy: 0.9604
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1838 - accuracy: 0.9621
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0908 - accuracy: 0.9785
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1639 - accuracy: 0.9660
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1305 - accuracy: 0.9708
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1603 - accuracy: 0.9642
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2030 - accuracy: 0.9571
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1878 - accuracy: 0.9521
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2530 - accuracy: 0.9386
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1085 - accuracy: 0.9750
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2302 - accuracy: 0.9456
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2028 - accuracy: 0.9536
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2377 - accuracy: 0.9450
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2097 - accuracy: 0.9475
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1796 - accuracy: 0.9602
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1245 - accuracy: 0.9743
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1380 - accuracy: 0.9657
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1690 - accuracy: 0.9648
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0924 - accuracy: 0.9801
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1989 - accuracy: 0.9506
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2288 - accuracy: 0.9536
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2043 - accuracy: 0.9583
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1649 - accuracy: 0.9612
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1598 - accuracy: 0.9594
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1919 - accuracy: 0.9497
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1655 - accuracy: 0.9583
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1485 - accuracy: 0.9644
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1597 - accuracy: 0.9629
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1831 - accuracy: 0.9531
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2751 - accuracy: 0.9427
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1240 - accuracy: 0.9698
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1434 - accuracy: 0.9708
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1772 - accuracy: 0.9601
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1390 - accuracy: 0.9627
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1605 - accuracy: 0.9688
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9915 - accuracy: 0.7778
#  75%|███████▌  | 3/4 [02:35<00:52, 52.85s/it]
# -------------------- Epoch 4 of 4 --------------------
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1255 - accuracy: 0.9707
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2460 - accuracy: 0.9388
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1995 - accuracy: 0.9542
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1428 - accuracy: 0.9696
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1282 - accuracy: 0.9698
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2116 - accuracy: 0.9504
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1047 - accuracy: 0.9771
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1773 - accuracy: 0.9536
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1731 - accuracy: 0.9615
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1757 - accuracy: 0.9612
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1611 - accuracy: 0.9600
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0805 - accuracy: 0.9817
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1514 - accuracy: 0.9615
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1715 - accuracy: 0.9577
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2267 - accuracy: 0.9509
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1030 - accuracy: 0.9768
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2091 - accuracy: 0.9502
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1455 - accuracy: 0.9664
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0822 - accuracy: 0.9779
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1962 - accuracy: 0.9434
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2352 - accuracy: 0.9441
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0931 - accuracy: 0.9756
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2970 - accuracy: 0.9330
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1562 - accuracy: 0.9634
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1149 - accuracy: 0.9728
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2456 - accuracy: 0.9442
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1758 - accuracy: 0.9577
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1649 - accuracy: 0.9607
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1612 - accuracy: 0.9615
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1151 - accuracy: 0.9746
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2475 - accuracy: 0.9352
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1207 - accuracy: 0.9725
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1785 - accuracy: 0.9547
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1456 - accuracy: 0.9604
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1433 - accuracy: 0.9708
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1934 - accuracy: 0.9515
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2654 - accuracy: 0.9479
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1490 - accuracy: 0.9587
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1483 - accuracy: 0.9637
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1904 - accuracy: 0.9509
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1844 - accuracy: 0.9531
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1535 - accuracy: 0.9698
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2526 - accuracy: 0.9386
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1916 - accuracy: 0.9515
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1028 - accuracy: 0.9775
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0854 - accuracy: 0.9777
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1310 - accuracy: 0.9679
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1816 - accuracy: 0.9547
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1218 - accuracy: 0.9698
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1387 - accuracy: 0.9609
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1623 - accuracy: 0.9607
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1140 - accuracy: 0.9708
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1064 - accuracy: 0.9741
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1748 - accuracy: 0.9547
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1287 - accuracy: 0.9708
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2240 - accuracy: 0.9510
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1497 - accuracy: 0.9600
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2475 - accuracy: 0.9386
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2021 - accuracy: 0.9531
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0848 - accuracy: 0.9795
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0919 - accuracy: 0.9798
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1481 - accuracy: 0.9637
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2110 - accuracy: 0.9526
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0959 - accuracy: 0.9721
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1674 - accuracy: 0.9571
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2496 - accuracy: 0.9362
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1184 - accuracy: 0.9667
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1733 - accuracy: 0.9588
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1586 - accuracy: 0.9607
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1762 - accuracy: 0.9567
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1194 - accuracy: 0.9709
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1870 - accuracy: 0.9510
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1465 - accuracy: 0.9657
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1949 - accuracy: 0.9492
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1839 - accuracy: 0.9515
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1635 - accuracy: 0.9561
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2207 - accuracy: 0.9449
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1433 - accuracy: 0.9627
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1763 - accuracy: 0.9569
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1196 - accuracy: 0.9718
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1312 - accuracy: 0.9678
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1009 - accuracy: 0.9746
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1117 - accuracy: 0.9721
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1389 - accuracy: 0.9644
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1599 - accuracy: 0.9556
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2237 - accuracy: 0.9422
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1907 - accuracy: 0.9564
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2596 - accuracy: 0.9375
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0887 - accuracy: 0.9776
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1376 - accuracy: 0.9677
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1409 - accuracy: 0.9570
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1888 - accuracy: 0.9512
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1552 - accuracy: 0.9677
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1556 - accuracy: 0.9614
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2008 - accuracy: 0.9443
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1019 - accuracy: 0.9731
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1037 - accuracy: 0.9740
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1707 - accuracy: 0.9600
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1447 - accuracy: 0.9637
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1751 - accuracy: 0.9587
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1205 - accuracy: 0.9688
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1521 - accuracy: 0.9583
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1196 - accuracy: 0.9705
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1758 - accuracy: 0.9531
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1321 - accuracy: 0.9677
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1331 - accuracy: 0.9677
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1977 - accuracy: 0.9542
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1598 - accuracy: 0.9542
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0774 - accuracy: 0.9775
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1229 - accuracy: 0.9698
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0776 - accuracy: 0.9801
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2185 - accuracy: 0.9469
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1167 - accuracy: 0.9798
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1144 - accuracy: 0.9732
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1285 - accuracy: 0.9619
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1890 - accuracy: 0.9515
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1312 - accuracy: 0.9635
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0952 - accuracy: 0.9735
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1220 - accuracy: 0.9707
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1423 - accuracy: 0.9646
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1437 - accuracy: 0.9648
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1354 - accuracy: 0.9615
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2598 - accuracy: 0.9448
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1450 - accuracy: 0.9656
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1183 - accuracy: 0.9709
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2284 - accuracy: 0.9408
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1345 - accuracy: 0.9639
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0968 - accuracy: 0.9774
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0901 - accuracy: 0.9744
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1770 - accuracy: 0.9551
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2036 - accuracy: 0.9536
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1933 - accuracy: 0.9605
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1848 - accuracy: 0.9525
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1251 - accuracy: 0.9718
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0830 - accuracy: 0.9757
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2180 - accuracy: 0.9404
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2458 - accuracy: 0.9422
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1795 - accuracy: 0.9594
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2053 - accuracy: 0.9512
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0595 - accuracy: 0.9829
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1091 - accuracy: 0.9750
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1534 - accuracy: 0.9634
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1917 - accuracy: 0.9507
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1915 - accuracy: 0.9561
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1359 - accuracy: 0.9646
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1516 - accuracy: 0.9623
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1946 - accuracy: 0.9486
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1067 - accuracy: 0.9708
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1334 - accuracy: 0.9617
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1313 - accuracy: 0.9656
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1627 - accuracy: 0.9598
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1651 - accuracy: 0.9615
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1024 - accuracy: 0.9708
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2104 - accuracy: 0.9549
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1077 - accuracy: 0.9748
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1531 - accuracy: 0.9580
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1265 - accuracy: 0.9677
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1701 - accuracy: 0.9549
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1030 - accuracy: 0.9784
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2016 - accuracy: 0.9644
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1771 - accuracy: 0.9565
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1348 - accuracy: 0.9617
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1018 - accuracy: 0.9717
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0889 - accuracy: 0.9768
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0718 - accuracy: 0.9834
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1017 - accuracy: 0.9752
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1492 - accuracy: 0.9631
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1287 - accuracy: 0.9697
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1529 - accuracy: 0.9627
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1235 - accuracy: 0.9667
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1135 - accuracy: 0.9708
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2555 - accuracy: 0.9434
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1257 - accuracy: 0.9651
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2063 - accuracy: 0.9492
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1496 - accuracy: 0.9634
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1017 - accuracy: 0.9707
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1735 - accuracy: 0.9635
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0874 - accuracy: 0.9835
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2431 - accuracy: 0.9460
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1035 - accuracy: 0.9782
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1460 - accuracy: 0.9625
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0645 - accuracy: 0.7963
# 100%|██████████| 4/4 [03:25<00:00, 51.36s/it]

# %% [markdown]
# # predicition of model

# %%
def prediction_on_bacth(model,tokens,tags):
  pred_tags_batch = []
  tokens_batch = []

  for x_batch,_,_ in batches_generator(1,tokens,tags,shuffle=False):
    prediction = model.predict(x_batch)
    pred_tags = []
    padded_batch = []
    tags_idxs_batch = np.argmax(prediction,axis=-1)
    for tags_idxs,token_idxs in zip(tags_idxs_batch,x_batch):
      pred_tags.append(idxs2tags(tags_idxs))
      padded_batch.append(idxs2words(token_idxs))
    pred_tags_batch.append(pred_tags)
    tokens_batch.append(padded_batch)
  
  return pred_tags_batch,tokens_batch

# %%
train_pred,pad_train = prediction_on_bacth(model,train_tokens,train_tags)
validation_pred,pad_val = prediction_on_bacth(model,validation_tokens,validation_tags)
test_pred,pad_test = prediction_on_bacth(model,test_tokens,test_tags)

# %%
def pred_lookup(tokens,pred_tags,actual_tags):
  for i in range(3):
    for token,pred,actual in zip(tokens[i][0],pred_tags[i][0],actual_tags[i]):
      print('%s\t%s\t%s' % (token, pred, actual))
    print('--------------')

# %%
pred_lookup(pad_train,train_pred,train_tags)
# Out:
# RT	O	O
# <USR>	O	O
# :	O	O
# Online	O	O
# ticket	O	O
# sales	O	O
# for	O	O
# Ghostland	B-other	B-musicartist
# Observatory	I-other	I-musicartist
# extended	O	O
# until	O	O
# 6	O	O
# PM	O	O
# EST	O	O
# due	O	O
# to	O	O
# high	O	O
# demand	O	O
# .	O	O
# Get	O	O
# them	O	O
# before	O	O
# they	O	O
# sell	O	O
# out	O	O
# ...	O	O
# --------------
# Apple	B-company	B-product
# MacBook	I-product	I-product
# Pro	I-product	I-product
# A1278	I-product	I-product
# 13.3	I-product	I-product
# "	I-product	I-product
# Laptop	I-product	I-product
# -	O	I-product
# MD101LL/A	I-product	I-product
# (	O	O
# June	O	O
# ,	O	O
# 2012	O	O
# )	O	O
# -	O	O
# Full	O	O
# read	O	O
# by	O	O
# eBay	O	B-company
# <URL>	O	O
# <URL>	O	O
# --------------
# Happy	O	O
# Birthday	O	O
# <USR>	O	O
# !	O	O
# May	O	O
# Allah	B-other	B-person
# s.w.t	O	O
# bless	O	O
# you	O	O
# with	O	O
# goodness	O	O
# and	O	O
# happiness	O	O
# .	O	O
# --------------

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import accuracy_score, f1_score , recall_score , average_precision_score

# %%
def eval(tags,pred):
  acc, f1 , recall, precision = [],[],[],[]
  for i in range(len(tags)):
    acc.append(accuracy_score(tags[i],pred[i][0]))
    f1.append(f1_score(tags[i],pred[i][0],average='weighted'))
    recall.append(recall_score(tags[i],pred[i][0],average='weighted'))
    #precision.append(average_precision_score(tags[i],pred[i][0],average='micro'))
  print('acc:',np.mean(acc),' f1_score :',np.mean(f1),'recall :',np.mean(recall))

# %%
print('-'*20 + ' Train Set quality:'+ '-'*20)
eval(train_tags,train_pred)

print('-'*20 + ' validation Set quality:'+ '-'*20)
eval(validation_tags,validation_pred)

print('-'*20 + ' Test Set quality:'+ '-'*20)
eval(test_tags,test_pred)
# Out:
# -------------------- Train Set quality:--------------------
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# acc: 0.9359819580002369  f1_score : 0.9280366734042187 recall : 0.9359819580002369
# -------------------- validation Set quality:--------------------
# acc: 0.9209864380034457  f1_score : 0.9103569844285917 recall : 0.9209864380034457
# -------------------- Test Set quality:--------------------
# acc: 0.9130420368235233  f1_score : 0.9030675345765647 recall : 0.9130420368235233
